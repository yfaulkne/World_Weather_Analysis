# %%
#Import Dependencies

import pandas as pd
import numpy as np
from citipy import citipy

# %%
#Create a set of random latitiue and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats,lngs)

lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
#Create a list for holding cities

cities = []

#Identify the nearest city for each lat and long combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    #If the city is unique, thenwe will add it to the cities list
    if city not in cities:
        cities.append(city)

#Print the city count to confirm sufficient count

len(cities)
# Out:
# 780

# %%
import time
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.

record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
 

    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        

        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country, 
                        "Current Weather": city_current
                        })
    
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | pevek
# Processing Record 4 of Set 1 | sorland
# Processing Record 5 of Set 1 | naze
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | palmer
# Processing Record 8 of Set 1 | atar
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | lukulu
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | vanimo
# Processing Record 13 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | dourbali
# Processing Record 16 of Set 1 | portland
# Processing Record 17 of Set 1 | oktyabrskiy
# Processing Record 18 of Set 1 | nishihara
# Processing Record 19 of Set 1 | hovin
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | cockburn town
# Processing Record 23 of Set 1 | san quintin
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | bathsheba
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | itarema
# Processing Record 30 of Set 1 | nadapuram
# Processing Record 31 of Set 1 | mount isa
# Processing Record 32 of Set 1 | coihaique
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | atambua
# Processing Record 36 of Set 1 | grindavik
# Processing Record 37 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | norman wells
# Processing Record 42 of Set 1 | xuddur
# Processing Record 43 of Set 1 | madang
# Processing Record 44 of Set 1 | zhigansk
# Processing Record 45 of Set 1 | vung tau
# Processing Record 46 of Set 1 | mayo
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | sapa
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | abalak
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | marawi
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | romny
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | kasongo-lunda
# Processing Record 13 of Set 2 | vestmannaeyjar
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | bud
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | puerto del rosario
# Processing Record 18 of Set 2 | koslan
# Processing Record 19 of Set 2 | maniitsoq
# Processing Record 20 of Set 2 | ust-kuyga
# Processing Record 21 of Set 2 | nalut
# Processing Record 22 of Set 2 | xichang
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | paris
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | anori
# Processing Record 28 of Set 2 | antofagasta
# Processing Record 29 of Set 2 | aklavik
# Processing Record 30 of Set 2 | husavik
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | nove straseci
# Processing Record 33 of Set 2 | formosa do rio preto
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | semey
# Processing Record 38 of Set 2 | maragogipe
# Processing Record 39 of Set 2 | kavaratti
# Processing Record 40 of Set 2 | pianco
# Processing Record 41 of Set 2 | zharkent
# Processing Record 42 of Set 2 | hirara
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | faanui
# Processing Record 45 of Set 2 | columbia
# Processing Record 46 of Set 2 | hare bay
# Processing Record 47 of Set 2 | urucara
# Processing Record 48 of Set 2 | saint anthony
# Processing Record 49 of Set 2 | pundaguitan
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | minab
# Processing Record 4 of Set 3 | taoudenni
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | auki
# Processing Record 7 of Set 3 | la ronge
# Processing Record 8 of Set 3 | jacareacanga
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | saint george
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | igarka
# Processing Record 13 of Set 3 | souillac
# Processing Record 14 of Set 3 | jamestown
# Processing Record 15 of Set 3 | sao filipe
# Processing Record 16 of Set 3 | asau
# Processing Record 17 of Set 3 | okhotsk
# Processing Record 18 of Set 3 | nikolskoye
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | banda aceh
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | svidnik
# Processing Record 24 of Set 3 | hambantota
# Processing Record 25 of Set 3 | saldanha
# Processing Record 26 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 3 | puerto escondido
# Processing Record 28 of Set 3 | smidovich
# Processing Record 29 of Set 3 | bluff
# Processing Record 30 of Set 3 | yabrud
# Processing Record 31 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 3 | staryy nadym
# Processing Record 33 of Set 3 | shasta lake
# Processing Record 34 of Set 3 | mandalgovi
# Processing Record 35 of Set 3 | narsaq
# Processing Record 36 of Set 3 | faya
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | turukhansk
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | mount gambier
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | te anau
# Processing Record 43 of Set 3 | colomi
# Processing Record 44 of Set 3 | venado tuerto
# Processing Record 45 of Set 3 | maltahohe
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | barra do garcas
# Processing Record 48 of Set 3 | viru
# Processing Record 49 of Set 3 | beihai
# Processing Record 50 of Set 3 | prince albert
# Processing Record 1 of Set 4 | celestun
# Processing Record 2 of Set 4 | rio grande
# Processing Record 3 of Set 4 | puri
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | ngunguru
# Processing Record 6 of Set 4 | udarnyy
# Processing Record 7 of Set 4 | empa
# City not found. Skipping...
# Processing Record 8 of Set 4 | colac
# Processing Record 9 of Set 4 | svetlyy
# Processing Record 10 of Set 4 | karpathos
# Processing Record 11 of Set 4 | coquimbo
# Processing Record 12 of Set 4 | maneadero
# Processing Record 13 of Set 4 | mangrol
# Processing Record 14 of Set 4 | half moon bay
# Processing Record 15 of Set 4 | beyneu
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | lagoa
# Processing Record 18 of Set 4 | tugulym
# Processing Record 19 of Set 4 | amazar
# Processing Record 20 of Set 4 | katunki
# City not found. Skipping...
# Processing Record 21 of Set 4 | cangucu
# Processing Record 22 of Set 4 | sunrise manor
# Processing Record 23 of Set 4 | mahasamund
# Processing Record 24 of Set 4 | laurel
# Processing Record 25 of Set 4 | vao
# Processing Record 26 of Set 4 | smoky lake
# Processing Record 27 of Set 4 | kingston
# Processing Record 28 of Set 4 | pisco
# Processing Record 29 of Set 4 | zyryanovsk
# Processing Record 30 of Set 4 | borogontsy
# Processing Record 31 of Set 4 | alofi
# Processing Record 32 of Set 4 | lafia
# Processing Record 33 of Set 4 | kavieng
# Processing Record 34 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 4 | port-gentil
# Processing Record 36 of Set 4 | saint-augustin
# Processing Record 37 of Set 4 | strezhevoy
# Processing Record 38 of Set 4 | komsomolskiy
# Processing Record 39 of Set 4 | bilma
# Processing Record 40 of Set 4 | soubre
# Processing Record 41 of Set 4 | mackay
# Processing Record 42 of Set 4 | new norfolk
# Processing Record 43 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 4 | bethel
# Processing Record 45 of Set 4 | tucuman
# Processing Record 46 of Set 4 | grand gaube
# Processing Record 47 of Set 4 | askiz
# Processing Record 48 of Set 4 | jiuquan
# Processing Record 49 of Set 4 | codrington
# Processing Record 50 of Set 4 | chapais
# Processing Record 1 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 2 of Set 5 | maridi
# Processing Record 3 of Set 5 | snasa
# Processing Record 4 of Set 5 | poum
# Processing Record 5 of Set 5 | kenora
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | port hedland
# Processing Record 8 of Set 5 | dandong
# Processing Record 9 of Set 5 | pointe michel
# Processing Record 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 5 | hami
# Processing Record 12 of Set 5 | laguna
# Processing Record 13 of Set 5 | tatarskaya pishlya
# Processing Record 14 of Set 5 | cassilandia
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | mirnyy
# Processing Record 17 of Set 5 | sikasso
# Processing Record 18 of Set 5 | lorengau
# Processing Record 19 of Set 5 | gizo
# Processing Record 20 of Set 5 | okandja
# City not found. Skipping...
# Processing Record 21 of Set 5 | ilulissat
# Processing Record 22 of Set 5 | sao joao da barra
# Processing Record 23 of Set 5 | prince george
# Processing Record 24 of Set 5 | magadi
# Processing Record 25 of Set 5 | general roca
# Processing Record 26 of Set 5 | qandala
# Processing Record 27 of Set 5 | jega
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | la rioja
# Processing Record 30 of Set 5 | gat
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | riyadh
# Processing Record 33 of Set 5 | avera
# Processing Record 34 of Set 5 | thunder bay
# Processing Record 35 of Set 5 | ulaanbaatar
# Processing Record 36 of Set 5 | mezen
# Processing Record 37 of Set 5 | qingquan
# Processing Record 38 of Set 5 | turayf
# Processing Record 39 of Set 5 | ketchikan
# Processing Record 40 of Set 5 | huarmey
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | troitskoye
# Processing Record 43 of Set 5 | guerrero negro
# Processing Record 44 of Set 5 | kemi
# Processing Record 45 of Set 5 | castro
# Processing Record 46 of Set 5 | goderich
# Processing Record 47 of Set 5 | san andres
# Processing Record 48 of Set 5 | doha
# Processing Record 49 of Set 5 | gao
# Processing Record 50 of Set 5 | isla mujeres
# Processing Record 1 of Set 6 | kokoda
# Processing Record 2 of Set 6 | jibuti
# Processing Record 3 of Set 6 | taga dzong
# City not found. Skipping...
# Processing Record 4 of Set 6 | nabinagar
# Processing Record 5 of Set 6 | dikson
# Processing Record 6 of Set 6 | praya
# Processing Record 7 of Set 6 | aitape
# Processing Record 8 of Set 6 | sredec
# City not found. Skipping...
# Processing Record 9 of Set 6 | gobabis
# Processing Record 10 of Set 6 | east london
# Processing Record 11 of Set 6 | ayorou
# Processing Record 12 of Set 6 | rocha
# Processing Record 13 of Set 6 | ornskoldsvik
# Processing Record 14 of Set 6 | awbari
# Processing Record 15 of Set 6 | petropavl
# Processing Record 16 of Set 6 | saint-georges
# Processing Record 17 of Set 6 | saint-joseph
# Processing Record 18 of Set 6 | pemangkat
# Processing Record 19 of Set 6 | marsaxlokk
# Processing Record 20 of Set 6 | vostok
# Processing Record 21 of Set 6 | tijuana
# Processing Record 22 of Set 6 | meulaboh
# Processing Record 23 of Set 6 | nuuk
# Processing Record 24 of Set 6 | port moresby
# Processing Record 25 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 6 | colorado springs
# Processing Record 27 of Set 6 | buta
# Processing Record 28 of Set 6 | mehamn
# Processing Record 29 of Set 6 | christchurch
# Processing Record 30 of Set 6 | moron
# Processing Record 31 of Set 6 | iracoubo
# Processing Record 32 of Set 6 | sheffield
# Processing Record 33 of Set 6 | sao goncalo
# Processing Record 34 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 6 | jumla
# Processing Record 36 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 6 | viedma
# Processing Record 38 of Set 6 | nurobod
# Processing Record 39 of Set 6 | sandy bay
# Processing Record 40 of Set 6 | iqaluit
# Processing Record 41 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 6 | nyurba
# Processing Record 43 of Set 6 | kralendijk
# Processing Record 44 of Set 6 | le pradet
# Processing Record 45 of Set 6 | kita
# Processing Record 46 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 47 of Set 6 | margate
# Processing Record 48 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 6 | ponta do sol
# Processing Record 50 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 1 of Set 7 | olutanga
# Processing Record 2 of Set 7 | waverly
# Processing Record 3 of Set 7 | bandarbeyla
# Processing Record 4 of Set 7 | pangody
# Processing Record 5 of Set 7 | bengkulu
# Processing Record 6 of Set 7 | mawlaik
# Processing Record 7 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 7 | murgab
# Processing Record 9 of Set 7 | katobu
# Processing Record 10 of Set 7 | kirakira
# Processing Record 11 of Set 7 | khandbari
# Processing Record 12 of Set 7 | leon valley
# Processing Record 13 of Set 7 | ionia
# Processing Record 14 of Set 7 | fort nelson
# Processing Record 15 of Set 7 | sitka
# Processing Record 16 of Set 7 | bourg-en-bresse
# Processing Record 17 of Set 7 | arys
# Processing Record 18 of Set 7 | masumbwe
# Processing Record 19 of Set 7 | yeppoon
# Processing Record 20 of Set 7 | ulaangom
# Processing Record 21 of Set 7 | valdivia
# Processing Record 22 of Set 7 | tosham
# Processing Record 23 of Set 7 | leningradskiy
# Processing Record 24 of Set 7 | los llanos de aridane
# Processing Record 25 of Set 7 | port hawkesbury
# Processing Record 26 of Set 7 | oussouye
# Processing Record 27 of Set 7 | horta
# Processing Record 28 of Set 7 | yatou
# Processing Record 29 of Set 7 | tateyama
# Processing Record 30 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 31 of Set 7 | carnarvon
# Processing Record 32 of Set 7 | wamba
# Processing Record 33 of Set 7 | chivilcoy
# Processing Record 34 of Set 7 | bafra
# Processing Record 35 of Set 7 | chuy
# Processing Record 36 of Set 7 | norden
# Processing Record 37 of Set 7 | brae
# Processing Record 38 of Set 7 | bayshore gardens
# Processing Record 39 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 7 | cherskiy
# Processing Record 41 of Set 7 | san cristobal
# Processing Record 42 of Set 7 | cheboksary
# Processing Record 43 of Set 7 | tezu
# Processing Record 44 of Set 7 | lodja
# Processing Record 45 of Set 7 | sioux lookout
# Processing Record 46 of Set 7 | cidreira
# Processing Record 47 of Set 7 | arraial do cabo
# Processing Record 48 of Set 7 | mazabuka
# Processing Record 49 of Set 7 | morros
# Processing Record 50 of Set 7 | koumra
# Processing Record 1 of Set 8 | hasaki
# Processing Record 2 of Set 8 | charlottetown
# Processing Record 3 of Set 8 | lensk
# Processing Record 4 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 5 of Set 8 | tieling
# Processing Record 6 of Set 8 | beringovskiy
# Processing Record 7 of Set 8 | rio gallegos
# Processing Record 8 of Set 8 | whitehorse
# Processing Record 9 of Set 8 | nome
# Processing Record 10 of Set 8 | iquitos
# Processing Record 11 of Set 8 | mocuba
# Processing Record 12 of Set 8 | khon buri
# Processing Record 13 of Set 8 | eureka
# Processing Record 14 of Set 8 | kahului
# Processing Record 15 of Set 8 | arani
# Processing Record 16 of Set 8 | chernyshevskiy
# Processing Record 17 of Set 8 | melilla
# Processing Record 18 of Set 8 | khasan
# Processing Record 19 of Set 8 | xining
# Processing Record 20 of Set 8 | chara
# Processing Record 21 of Set 8 | awjilah
# Processing Record 22 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 8 | batamshinskiy
# Processing Record 25 of Set 8 | chicama
# Processing Record 26 of Set 8 | tiksi
# Processing Record 27 of Set 8 | tilichiki
# Processing Record 28 of Set 8 | eatonton
# Processing Record 29 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 8 | labytnangi
# Processing Record 31 of Set 8 | mapiripan
# Processing Record 32 of Set 8 | bonavista
# Processing Record 33 of Set 8 | tall kayf
# Processing Record 34 of Set 8 | kununurra
# Processing Record 35 of Set 8 | clyde river
# Processing Record 36 of Set 8 | sehithwa
# Processing Record 37 of Set 8 | mae ramat
# Processing Record 38 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 8 | oktyabrskoye
# Processing Record 40 of Set 8 | bouza
# Processing Record 41 of Set 8 | darnah
# Processing Record 42 of Set 8 | kloulklubed
# Processing Record 43 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 8 | south lake tahoe
# Processing Record 45 of Set 8 | karpogory
# Processing Record 46 of Set 8 | yulara
# Processing Record 47 of Set 8 | puerto narino
# Processing Record 48 of Set 8 | vuktyl
# Processing Record 49 of Set 8 | stornoway
# Processing Record 50 of Set 8 | pangnirtung
# Processing Record 1 of Set 9 | kimry
# Processing Record 2 of Set 9 | fairmont
# Processing Record 3 of Set 9 | san-pedro
# Processing Record 4 of Set 9 | baijiantan
# Processing Record 5 of Set 9 | juegang
# Processing Record 6 of Set 9 | vestmanna
# Processing Record 7 of Set 9 | dhidhdhoo
# Processing Record 8 of Set 9 | sadao
# Processing Record 9 of Set 9 | leh
# Processing Record 10 of Set 9 | taltal
# Processing Record 11 of Set 9 | wewak
# Processing Record 12 of Set 9 | tevaitoa
# Processing Record 13 of Set 9 | beloha
# Processing Record 14 of Set 9 | bubaque
# Processing Record 15 of Set 9 | nacala
# Processing Record 16 of Set 9 | lossiemouth
# Processing Record 17 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 18 of Set 9 | lasa
# Processing Record 19 of Set 9 | evinayong
# Processing Record 20 of Set 9 | opunake
# Processing Record 21 of Set 9 | platanos
# Processing Record 22 of Set 9 | esperance
# Processing Record 23 of Set 9 | vila
# Processing Record 24 of Set 9 | talnakh
# Processing Record 25 of Set 9 | san matias
# Processing Record 26 of Set 9 | katsuura
# Processing Record 27 of Set 9 | bambous virieux
# Processing Record 28 of Set 9 | lazaro cardenas
# Processing Record 29 of Set 9 | chokwe
# Processing Record 30 of Set 9 | llanes
# Processing Record 31 of Set 9 | lata
# Processing Record 32 of Set 9 | kushiro
# Processing Record 33 of Set 9 | praia da vitoria
# Processing Record 34 of Set 9 | alta floresta
# Processing Record 35 of Set 9 | harper
# Processing Record 36 of Set 9 | ostrovnoy
# Processing Record 37 of Set 9 | tera
# Processing Record 38 of Set 9 | namatanai
# Processing Record 39 of Set 9 | salinas
# Processing Record 40 of Set 9 | gladstone
# Processing Record 41 of Set 9 | kyra
# Processing Record 42 of Set 9 | yumen
# Processing Record 43 of Set 9 | matamoros
# Processing Record 44 of Set 9 | angola
# Processing Record 45 of Set 9 | lebu
# Processing Record 46 of Set 9 | gravelbourg
# Processing Record 47 of Set 9 | abu samrah
# Processing Record 48 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 9 | sechura
# Processing Record 1 of Set 10 | ancud
# Processing Record 2 of Set 10 | rawson
# Processing Record 3 of Set 10 | chauk
# Processing Record 4 of Set 10 | tukrah
# Processing Record 5 of Set 10 | ibanda
# Processing Record 6 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 10 | bowen
# Processing Record 8 of Set 10 | marsabit
# Processing Record 9 of Set 10 | mandurah
# Processing Record 10 of Set 10 | daru
# Processing Record 11 of Set 10 | rizhao
# Processing Record 12 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 13 of Set 10 | shilka
# Processing Record 14 of Set 10 | richards bay
# Processing Record 15 of Set 10 | bratsk
# Processing Record 16 of Set 10 | kysyl-syr
# Processing Record 17 of Set 10 | mamburao
# Processing Record 18 of Set 10 | ola
# Processing Record 19 of Set 10 | neiafu
# Processing Record 20 of Set 10 | ekhabi
# Processing Record 21 of Set 10 | garmsar
# Processing Record 22 of Set 10 | dujuma
# City not found. Skipping...
# Processing Record 23 of Set 10 | jalu
# Processing Record 24 of Set 10 | sokoto
# Processing Record 25 of Set 10 | copiapo
# Processing Record 26 of Set 10 | caravelas
# Processing Record 27 of Set 10 | hammond
# Processing Record 28 of Set 10 | constitucion
# Processing Record 29 of Set 10 | khalkhal
# Processing Record 30 of Set 10 | klaksvik
# Processing Record 31 of Set 10 | bay roberts
# Processing Record 32 of Set 10 | morgan city
# Processing Record 33 of Set 10 | korla
# Processing Record 34 of Set 10 | topolovgrad
# Processing Record 35 of Set 10 | srednekolymsk
# Processing Record 36 of Set 10 | ust-ilimsk
# Processing Record 37 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 10 | berlevag
# Processing Record 39 of Set 10 | chemodanovka
# Processing Record 40 of Set 10 | corn island
# Processing Record 41 of Set 10 | cheremukhovo
# Processing Record 42 of Set 10 | bundaberg
# Processing Record 43 of Set 10 | kungurtug
# Processing Record 44 of Set 10 | kirovskiy
# Processing Record 45 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 10 | campo formoso
# Processing Record 47 of Set 10 | kamina
# Processing Record 48 of Set 10 | hobyo
# Processing Record 49 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 50 of Set 10 | nizwa
# Processing Record 1 of Set 11 | mhango
# Processing Record 2 of Set 11 | florianopolis
# Processing Record 3 of Set 11 | kudahuvadhoo
# Processing Record 4 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 11 | eldorado
# Processing Record 6 of Set 11 | pashiya
# Processing Record 7 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 11 | harer
# Processing Record 9 of Set 11 | ardakan
# Processing Record 10 of Set 11 | aleksandrovskoye
# Processing Record 11 of Set 11 | vilhena
# Processing Record 12 of Set 11 | onega
# Processing Record 13 of Set 11 | sabang
# Processing Record 14 of Set 11 | launceston
# Processing Record 15 of Set 11 | uray
# Processing Record 16 of Set 11 | vagur
# Processing Record 17 of Set 11 | kozhva
# Processing Record 18 of Set 11 | quelimane
# Processing Record 19 of Set 11 | walvis bay
# Processing Record 20 of Set 11 | baft
# Processing Record 21 of Set 11 | teguldet
# Processing Record 22 of Set 11 | hamilton
# Processing Record 23 of Set 11 | pasni
# Processing Record 24 of Set 11 | dzilam gonzalez
# Processing Record 25 of Set 11 | cheremshanka
# Processing Record 26 of Set 11 | isabela
# Processing Record 27 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 11 | nadvoitsy
# Processing Record 29 of Set 11 | winsum
# Processing Record 30 of Set 11 | veraval
# Processing Record 31 of Set 11 | svetlogorsk
# Processing Record 32 of Set 11 | saint-pierre
# Processing Record 33 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 11 | limulunga
# Processing Record 35 of Set 11 | dingle
# Processing Record 36 of Set 11 | adrar
# Processing Record 37 of Set 11 | manggar
# Processing Record 38 of Set 11 | san jeronimo
# Processing Record 39 of Set 11 | boffa
# Processing Record 40 of Set 11 | sangre grande
# Processing Record 41 of Set 11 | sola
# Processing Record 42 of Set 11 | lazi
# Processing Record 43 of Set 11 | najran
# Processing Record 44 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 11 | marzuq
# Processing Record 47 of Set 11 | koszalin
# Processing Record 48 of Set 11 | denpasar
# Processing Record 49 of Set 11 | lugovoy
# Processing Record 50 of Set 11 | riachao do dantas
# Processing Record 1 of Set 12 | labuan
# Processing Record 2 of Set 12 | vazhiny
# Processing Record 3 of Set 12 | skelmersdale
# Processing Record 4 of Set 12 | bahia blanca
# Processing Record 5 of Set 12 | gornopravdinsk
# Processing Record 6 of Set 12 | banos
# Processing Record 7 of Set 12 | sabha
# Processing Record 8 of Set 12 | muros
# Processing Record 9 of Set 12 | shache
# Processing Record 10 of Set 12 | nara
# Processing Record 11 of Set 12 | hokitika
# Processing Record 12 of Set 12 | grand haven
# Processing Record 13 of Set 12 | port hardy
# Processing Record 14 of Set 12 | south venice
# Processing Record 15 of Set 12 | luena
# Processing Record 16 of Set 12 | paveh
# Processing Record 17 of Set 12 | nikolayevka
# Processing Record 18 of Set 12 | bentiu
# Processing Record 19 of Set 12 | okolona
# Processing Record 20 of Set 12 | portobelo
# Processing Record 21 of Set 12 | we
# City not found. Skipping...
# Processing Record 22 of Set 12 | carinhanha
# Processing Record 23 of Set 12 | isiro
# Processing Record 24 of Set 12 | shizunai
# Processing Record 25 of Set 12 | voh
# Processing Record 26 of Set 12 | tromso
# Processing Record 27 of Set 12 | paragominas
# Processing Record 28 of Set 12 | certegui
# Processing Record 29 of Set 12 | paamiut
# Processing Record 30 of Set 12 | forestville
# Processing Record 31 of Set 12 | arona
# Processing Record 32 of Set 12 | biak
# Processing Record 33 of Set 12 | dublin
# Processing Record 34 of Set 12 | gazanjyk
# Processing Record 35 of Set 12 | fairbanks
# Processing Record 36 of Set 12 | porbandar
# Processing Record 37 of Set 12 | itoman
# Processing Record 38 of Set 12 | klyuchi
# Processing Record 39 of Set 12 | baykit
# Processing Record 40 of Set 12 | okakarara
# Processing Record 41 of Set 12 | haines junction
# Processing Record 42 of Set 12 | astoria
# Processing Record 43 of Set 12 | dumas
# Processing Record 44 of Set 12 | darhan
# Processing Record 45 of Set 12 | comodoro rivadavia
# Processing Record 46 of Set 12 | along
# Processing Record 47 of Set 12 | shahpura
# Processing Record 48 of Set 12 | broome
# Processing Record 49 of Set 12 | tehuacan
# Processing Record 50 of Set 12 | naliya
# Processing Record 1 of Set 13 | makakilo city
# Processing Record 2 of Set 13 | teya
# Processing Record 3 of Set 13 | wanning
# Processing Record 4 of Set 13 | layou
# Processing Record 5 of Set 13 | kamaishi
# Processing Record 6 of Set 13 | banjar
# Processing Record 7 of Set 13 | mamallapuram
# Processing Record 8 of Set 13 | yambio
# Processing Record 9 of Set 13 | kompaniyivka
# Processing Record 10 of Set 13 | raga
# Processing Record 11 of Set 13 | hohhot
# Processing Record 12 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 13 | evensk
# Processing Record 14 of Set 13 | cap malheureux
# Processing Record 15 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 13 | jaru
# Processing Record 17 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 18 of Set 13 | saint-denis
# Processing Record 19 of Set 13 | namibe
# Processing Record 20 of Set 13 | kruisfontein
# Processing Record 21 of Set 13 | zhengjiatun
# Processing Record 22 of Set 13 | bojaya
# City not found. Skipping...
# Processing Record 23 of Set 13 | malmesbury
# Processing Record 24 of Set 13 | lesogorsk
# Processing Record 25 of Set 13 | saurimo
# Processing Record 26 of Set 13 | inirida
# Processing Record 27 of Set 13 | olafsvik
# Processing Record 28 of Set 13 | egvekinot
# Processing Record 29 of Set 13 | novaya zaimka
# Processing Record 30 of Set 13 | teluk nibung
# Processing Record 31 of Set 13 | honningsvag
# Processing Record 32 of Set 13 | zilair
# Processing Record 33 of Set 13 | port macquarie
# Processing Record 34 of Set 13 | hualmay
# Processing Record 35 of Set 13 | canutama
# Processing Record 36 of Set 13 | yerofey pavlovich
# Processing Record 37 of Set 13 | benguela
# Processing Record 38 of Set 13 | vanavara
# Processing Record 39 of Set 13 | sanming
# Processing Record 40 of Set 13 | dudinka
# Processing Record 41 of Set 13 | ulcinj
# Processing Record 42 of Set 13 | aldan
# Processing Record 43 of Set 13 | leshukonskoye
# Processing Record 44 of Set 13 | carroll
# Processing Record 45 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 13 | inhambane
# Processing Record 47 of Set 13 | yangambi
# Processing Record 48 of Set 13 | norfolk
# Processing Record 49 of Set 13 | altagracia de orituco
# Processing Record 50 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 14 | giulianova
# Processing Record 2 of Set 14 | balkanabat
# Processing Record 3 of Set 14 | nago
# Processing Record 4 of Set 14 | mvuma
# Processing Record 5 of Set 14 | anchorage
# Processing Record 6 of Set 14 | lahat
# Processing Record 7 of Set 14 | washington
# Processing Record 8 of Set 14 | gulu
# Processing Record 9 of Set 14 | la palma
# Processing Record 10 of Set 14 | rosario do sul
# Processing Record 11 of Set 14 | tura
# Processing Record 12 of Set 14 | shimanovsk
# Processing Record 13 of Set 14 | shelburne
# Processing Record 14 of Set 14 | ebano
# City not found. Skipping...
# Processing Record 15 of Set 14 | sibolga
# Processing Record 16 of Set 14 | khorixas
# Processing Record 17 of Set 14 | ivot
# Processing Record 18 of Set 14 | jinchang
# Processing Record 19 of Set 14 | alice springs
# Processing Record 20 of Set 14 | emerald
# Processing Record 21 of Set 14 | agua buena
# Processing Record 22 of Set 14 | salalah
# Processing Record 23 of Set 14 | omboue
# Processing Record 24 of Set 14 | cruz grande
# Processing Record 25 of Set 14 | vila velha
# Processing Record 26 of Set 14 | divnoye
# Processing Record 27 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 14 | parati
# Processing Record 29 of Set 14 | gorahun
# Processing Record 30 of Set 14 | santa marta
# Processing Record 31 of Set 14 | kendal
# Processing Record 32 of Set 14 | ambagarh chauki
# Processing Record 33 of Set 14 | olinda
# Processing Record 34 of Set 14 | valentin gomez farias
# Processing Record 35 of Set 14 | zhangye
# Processing Record 36 of Set 14 | mehndawal
# Processing Record 37 of Set 14 | mazagao
# Processing Record 38 of Set 14 | maryborough
# Processing Record 39 of Set 14 | zhezkazgan
# Processing Record 40 of Set 14 | tambul
# City not found. Skipping...
# Processing Record 41 of Set 14 | u thong
# Processing Record 42 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 14 | vila franca do campo
# Processing Record 44 of Set 14 | bougouni
# Processing Record 45 of Set 14 | hofn
# Processing Record 46 of Set 14 | kristiansund
# Processing Record 47 of Set 14 | orlik
# Processing Record 48 of Set 14 | eyl
# Processing Record 49 of Set 14 | mogadishu
# Processing Record 50 of Set 14 | mersing
# Processing Record 1 of Set 15 | juneau
# Processing Record 2 of Set 15 | verkhoyansk
# Processing Record 3 of Set 15 | inta
# Processing Record 4 of Set 15 | kapit
# Processing Record 5 of Set 15 | portsmouth
# Processing Record 6 of Set 15 | dalbandin
# Processing Record 7 of Set 15 | lavrentiya
# Processing Record 8 of Set 15 | shkotovo-22
# City not found. Skipping...
# Processing Record 9 of Set 15 | orda
# Processing Record 10 of Set 15 | domna
# Processing Record 11 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 15 | north bend
# Processing Record 13 of Set 15 | port blair
# Processing Record 14 of Set 15 | westport
# Processing Record 15 of Set 15 | san juan
# Processing Record 16 of Set 15 | barahona
# Processing Record 17 of Set 15 | sayyan
# Processing Record 18 of Set 15 | sept-iles
# Processing Record 19 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 20 of Set 15 | khandagayty
# Processing Record 21 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 15 | eskisehir
# Processing Record 23 of Set 15 | saint-francois
# Processing Record 24 of Set 15 | talcahuano
# Processing Record 25 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 15 | san lorenzo
# Processing Record 27 of Set 15 | manono
# Processing Record 28 of Set 15 | deputatskiy
# Processing Record 29 of Set 15 | waipawa
# Processing Record 30 of Set 15 | sisimiut
# Processing Record 31 of Set 15 | mindelo
# Processing Record 32 of Set 15 | labuhan
# Processing Record 33 of Set 15 | cherkasskoye
# Processing Record 34 of Set 15 | ludwigsfelde
# Processing Record 35 of Set 15 | tautira
# Processing Record 36 of Set 15 | cayenne
# Processing Record 37 of Set 15 | bom jesus do galho
# Processing Record 38 of Set 15 | calvia
# Processing Record 39 of Set 15 | arrecife
# Processing Record 40 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 15 | presque isle
# Processing Record 42 of Set 15 | yendi
# Processing Record 43 of Set 15 | ilebo
# Processing Record 44 of Set 15 | rupert
# Processing Record 45 of Set 15 | arteaga
# Processing Record 46 of Set 15 | san luis
# Processing Record 47 of Set 15 | killarney
# Processing Record 48 of Set 15 | padang
# Processing Record 49 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 50 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 16 | ahipara
# Processing Record 2 of Set 16 | touros
# Processing Record 3 of Set 16 | krasnoyarka
# Processing Record 4 of Set 16 | dharchula
# Processing Record 5 of Set 16 | tazmalt
# Processing Record 6 of Set 16 | mattawa
# Processing Record 7 of Set 16 | abu dhabi
# Processing Record 8 of Set 16 | baracoa
# Processing Record 9 of Set 16 | port-de-paix
# City not found. Skipping...
# Processing Record 10 of Set 16 | baoro
# Processing Record 11 of Set 16 | mountain home
# Processing Record 12 of Set 16 | maceio
# Processing Record 13 of Set 16 | salamiyah
# Processing Record 14 of Set 16 | maldonado
# Processing Record 15 of Set 16 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 16 | krasnogorodsk
# Processing Record 17 of Set 16 | tongliao
# Processing Record 18 of Set 16 | krasnoselkup
# Processing Record 19 of Set 16 | port augusta
# Processing Record 20 of Set 16 | barkot
# Processing Record 21 of Set 16 | buchanan
# Processing Record 22 of Set 16 | saint-die
# City not found. Skipping...
# Processing Record 23 of Set 16 | moose factory
# Processing Record 24 of Set 16 | hajiganj
# Processing Record 25 of Set 16 | tahe
# Processing Record 26 of Set 16 | ukiah
# Processing Record 27 of Set 16 | bilibino
# Processing Record 28 of Set 16 | inuvik
# Processing Record 29 of Set 16 | vieux-habitants
# Processing Record 30 of Set 16 | russell
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Lompoc  34.6391 -120.4579     66.02        66          40
# 1  Puerto Ayora  -0.7393  -90.3518     75.16        84          49
# 2         Pevek  69.7008  170.3133      9.61        94          85
# 3       Sorland  67.6670   12.6934     41.40        77          97
# 4          Naze  28.3667  129.4833     72.52        92         100
# 5        Atuona  -9.8000 -139.0333     79.05        75          39
# 6        Palmer  42.1584  -72.3287     62.20        32          20
# 7          Atar  20.5169  -13.0499     78.78        19          37
# 8       Rikitea -23.1203 -134.9692     70.77        89         100
# 9        Lukulu -14.3707   23.2420     62.71        87          95
#
#    Wind Speed Country       Current Weather
# 0       19.57      US      scattered clouds
# 1        9.26      EC      scattered clouds
# 2        5.97      RU       overcast clouds
# 3       17.78      NO       overcast clouds
# 4       10.16      JP       overcast clouds
# 5       12.84      PF      scattered clouds
# 6       14.97      US            few clouds
# 7        6.69      MR      scattered clouds
# 8        6.40      PF  heavy intensity rain
# 9        3.78      ZM       overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Weather']

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Lompoc      US  34.6391 -120.4579     66.02        66          40
# 1  Puerto Ayora      EC  -0.7393  -90.3518     75.16        84          49
# 2         Pevek      RU  69.7008  170.3133      9.61        94          85
# 3       Sorland      NO  67.6670   12.6934     41.40        77          97
# 4          Naze      JP  28.3667  129.4833     72.52        92         100
# 5        Atuona      PF  -9.8000 -139.0333     79.05        75          39
# 6        Palmer      US  42.1584  -72.3287     62.20        32          20
# 7          Atar      MR  20.5169  -13.0499     78.78        19          37
# 8       Rikitea      PF -23.1203 -134.9692     70.77        89         100
# 9        Lukulu      ZM -14.3707   23.2420     62.71        87          95
#
#    Wind Speed       Current Weather
# 0       19.57      scattered clouds
# 1        9.26      scattered clouds
# 2        5.97       overcast clouds
# 3       17.78       overcast clouds
# 4       10.16       overcast clouds
# 5       12.84      scattered clouds
# 6       14.97            few clouds
# 7        6.69      scattered clouds
# 8        6.40  heavy intensity rain
# 9        3.78       overcast clouds

# %%
# Create the output file (CSV)

output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV

city_data_df.to_csv(output_data_file, index_label="City_ID")
